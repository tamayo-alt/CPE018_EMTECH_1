# %% [markdown]
# <a href="https://colab.research.google.com/github/tamayo-alt/CPE018_EMTECH_1/blob/main/Q31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import cv2 as CV
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = cv2.imread('/content/drive/MyDrive/EMTECH FOLD/Copy of nature.jpg')
image = cv2.imread('/content/drive/MyDrive/EMTECH FOLD/Copy of nature.jpg')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
img = cv2.cvtColor(path, CV.COLOR_BGR2GRAY)
image = cv2.resize(image, (300, 300))
img = cv2.resize(img, (300, 300))
plt.imshow(image, cmap='gray')
plt.show()
